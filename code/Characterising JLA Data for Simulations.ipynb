# %%
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
import seaborn as sns
from reader import *

radra+=pi
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f, ax = subplots(2, 2)

ax[0,0].hist(zs)
ax[0,0].set_title('zs')
ax[0,1].hist(mus)
ax[0,1].set_title('mus')
ax[1,0].hist(mues)
ax[1,0].set_title('mues')
ax[1,1].hist(ras, label='ras')
ax[1,1].hist(decs, label='decs')
ax[1,1].legend()

# %%
import scipy.stats as stats

sns.distplot(zs, kde=False, fit=stats.lognorm)

# %%
g = sns.FacetGrid(jla, hue="SURVEY", size=6)
g.map(plt.scatter, "z", "msbe")
g.add_legend()

# %%
p = sns.FacetGrid(jla, hue="SURVEY", size=6)
p.map(plt.scatter, "z", "msb", alpha=0.6)
p.add_legend()
