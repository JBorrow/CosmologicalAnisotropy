# %%
# %pylab inline
import pymc, mcmcsetup_jla_v2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
R = pymc.MCMC(mcmcsetup_jla_v2)

# %%
R.sample(20000)
# Out:
#  [-----------------100%-----------------] 20001 of 20000 complete in 2419.2 sec

# %%
print(R.omegaB.value)
# Out:
# 0.4876980117059212

# %%
from pymc.Matplot import plot

plot(R)
# Out:
# Plotting leff
# Plotting omegaB
