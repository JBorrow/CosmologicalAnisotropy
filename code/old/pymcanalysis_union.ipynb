# %%
# %pylab inline
import pymc, mcmcsetup_union
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib

# %%
R = pymc.MCMC(mcmcsetup_union)

# %%
R.sample(5000)
# Out:
#  [-----------------100%-----------------] 5000 of 5000 complete in 464.4 sec

# %%
print(R.omegaB.value)
# Out:
# 0.2617062044264046

# %%
from pymc.Matplot import plot

plot(R)
# Out:
# Plotting omegaB
# Plotting leff
